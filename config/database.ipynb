# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
DB_USER = os.getenv("DB_USERNAME")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_DATABASE")

# %%
from sqlalchemy import create_engine

engine = create_engine(f"mysql+mysqlconnector://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# %%
import pandas as pd

df = pd.read_sql("SELECT * FROM transaction_data", engine)
print(df.head())
# Out:
#   Transaction ID Sender Account ID Receiver Account ID  Transaction Amount  \
# 0  TXN4363205433          ACC83609            ACC14505             4106.87
# 1  TXN3391510523          ACC68952            ACC80170             1977.30
# 2  TXN6911591624          ACC90406            ACC37430             2256.67
# 3  TXN4662526045          ACC60425            ACC74426             4636.06
# 4  TXN3490372585          ACC23270            ACC29470             3125.88
#
#   Transaction Type            Timestamp Transaction Status Fraud Flag  \
# 0          Deposit  2025-01-01 00:04:49            Success      FALSE
# 1       Withdrawal  2025-01-01 00:08:44            Success      FALSE
# 2         Transfer  2025-01-01 00:12:54            Success      FALSE
# 3       Withdrawal  2025-01-01 00:13:12            Success      FALSE
# 4       Withdrawal  2025-01-01 00:14:29            Success      FALSE
#
#   Geolocation (Latitude/Longitude) Device Used Network Slice ID  Latency (ms)  \
# 0              51.5074 N, 0.1278 W      Mobile           Slice1            89
# 1             34.0522 N, -74.006 W     Desktop           Slice1            64
# 2             55.7558 N, 37.6173 W      Mobile           Slice3            90
# 3              51.5074 N, 0.1278 W     Desktop           Slice1            20
# 4              51.5074 N, 0.1278 W      Mobile           Slice1            41
#
#    Slice Bandwidth (Mbps)  PIN Code
# 0                     486      6445
# 1                     554      4888
# 2                    1979      7010
# 3                    1832      3834
# 4                     548      2317

# %%
def save_to_sql(dataframe, table_name):
    dataframe.to_sql(
        table_name,
        con=engine,
        if_exists='replace',
        index=False
    )
    print(f"{table_name} saved successfully")

save_to_sql(
    dataframe=df,
    table_name="clean_transaction_data"
)

print("Clean data saved")
# Out:
# clean_transaction_data saved successfully
# Clean data saved
